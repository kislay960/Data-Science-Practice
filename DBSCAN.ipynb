# %% [markdown]
# <a href="https://colab.research.google.com/github/kislay960/Data-Science-Practice/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles,make_moons

X,Y = make_moons(n_samples=200,noise=0.10)
plt.scatter(X[:,0],X[:,1],c=Y)
plt.show()

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=2)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = km.cluster_centers_
label = km.labels_

plt.scatter(X[:,0],X[:,1],c=label)
plt.scatter(centers[:,0],centers[:,1],color='red')
plt.show()

# %% [markdown]
# KMeans can still fail!
# We will use DBSCAN.

# %%
from sklearn.cluster import DBSCAN

# %%
dbs = DBSCAN(eps=0.21,min_samples=5)
dbs.fit(X)
# Out:
# DBSCAN(algorithm='auto', eps=0.21, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
Ypred = dbs.fit_predict(X)
plt.scatter(X[:,0],X[:,1],c=Ypred)
plt.show()
