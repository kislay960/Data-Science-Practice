# %% [markdown]
# <a href="https://colab.research.google.com/github/kislay960/Data-Science-Practice/blob/main/Transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102973440/102967424 [==============================] - 1s 0us/step

# %%
import cv2
img_path = '/content/drive/MyDrive/images/dogs/dog.100.jpg'
img = cv2.imread(img_path)
img = cv2.resize(img,(224,224))
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
import matplotlib.pyplot as plt
plt.title("Actual Image")
plt.imshow(img)
plt.show()
plt.title("Normalised Image")
plt.imshow(x[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.5162309), ('n02093991', 'Irish_terrier', 0.19587526), ('n02090379', 'redbone', 0.18434288)]
