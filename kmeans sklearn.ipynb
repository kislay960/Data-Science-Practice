# %% [markdown]
# <a href="https://colab.research.google.com/github/kislay960/Data-Science-Practice/blob/main/kmeans%20sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
x,y = make_blobs(n_samples= 1000, n_features= 2, centers =5, random_state=3)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(x,y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = kmeans.cluster_centers_

# %%
plt.scatter(x[:,0],x[:,1])
plt.scatter(centers[:,0],centers[:,1],marker='*',color='orange')
plt.show()

# %%
pred = kmeans.labels_

# %%
plt.scatter(x[:,0],x[:,1],c=pred)
plt.scatter(centers[:,0],centers[:,1],marker='*',color='black')
plt.title("Prediction")
plt.show()

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.title("Actual")
plt.show()

# %%
kmeans.inertia_
# Out:
# 2007.0183198254567
