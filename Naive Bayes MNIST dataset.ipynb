# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import cross_val_score
import numpy as np
import matplotlib.pyplot as plt

# %%
digits = load_digits()

# %%
x = digits.data
y = digits.target

# %%
plt.imshow(x[0].reshape((8,-1)))
plt.show()
print(y[0])
# Out:
# 0

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB

# %%
gnb = GaussianNB()
mnb = MultinomialNB()

# %%
gnb.fit(x,y)
mnb.fit(x,y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print(gnb.score(x,y))
print(mnb.score(x,y))
# Out:
# 0.8580968280467446
# 0.9053978853644964

# %% [markdown]
# MNB is giving higher accuracy as the data is discrete. GNB is suitable for continous datasets(bell shaped curve)

# %%
cross_val_score(gnb,x,y,scoring='accuracy',cv=10).mean()
# Out:
# 0.8113904407200497

# %%
cross_val_score(mnb,x,y,scoring='accuracy',cv=10).mean()
# Out:
# 0.8797858472998138
